# %% [markdown]
# # Mercari(일본 중고거래 플랫폼) 가격 예측 프로젝트
#
# ## 프로젝트 흐름
# 1. 환경 설정 및 데이터 로드
# 2. 데이터 전처리 (카테고리 분리, 결측치 처리)
# 3. 텍스트 특징 추출 (NLP_자연어 처리)
# 4. 새로운 피처 생성
# 5. 모델 학습
# 6. 가격 예측 & 제출
#
# ### 1. 환경설정 및 데이터 로드

# %%
pip install pandas numpy scikit-learn lightgbm nltk scipy
# Out:
# Requirement already satisfied: pandas in c:\users\tg\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\tg\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: scikit-learn in c:\users\tg\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: lightgbm in c:\users\tg\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: nltk in c:\users\tg\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: scipy in c:\users\tg\anaconda3\lib\site-packages (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tg\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tg\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tg\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tg\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tg\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: click in c:\users\tg\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\tg\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\tg\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\tg\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\tg\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1. 환경설정
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

# 1. 데이터 로드
train = pd.read_csv('train.tsv', sep='\t')
test  = pd.read_csv('test.tsv',  sep='\t')

print(train.shape)
print(train.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\TG\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\TG\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\TG\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# (1482535, 8)
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482535 entries, 0 to 1482534
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   train_id           1482535 non-null  int64
#  1   name               1482535 non-null  object
#  2   item_condition_id  1482535 non-null  int64
#  3   category_name      1476208 non-null  object
#  4   brand_name         849853 non-null   object
#  5   price              1482535 non-null  float64
#  6   shipping           1482535 non-null  int64
#  7   item_description   1482529 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 90.5+ MB

# %%
train.describe()
# Out:
#            train_id  item_condition_id         price      shipping
# count  1.482535e+06       1.482535e+06  1.482535e+06  1.482535e+06
# mean   7.412670e+05       1.907380e+00  2.673752e+01  4.472744e-01
# std    4.279711e+05       9.031586e-01  3.858607e+01  4.972124e-01
# min    0.000000e+00       1.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.706335e+05       1.000000e+00  1.000000e+01  0.000000e+00
# 50%    7.412670e+05       2.000000e+00  1.700000e+01  0.000000e+00
# 75%    1.111900e+06       3.000000e+00  2.900000e+01  1.000000e+00
# max    1.482534e+06       5.000000e+00  2.009000e+03  1.000000e+00

# %%
train['item_condition_id'].unique() # 수치형 컬럼이지만 상태의 등급을 수치로 표현
# Out:
# array([3, 1, 2, 4, 5])

# %%
train['shipping'].unique() # 수치형 컬럼이지만 배송 유무에 대한 것을 수치로 표현
# Out:
# array([1, 0])

# %%
# 수치형 컬럼 선택
numeric_cols = ['item_condition_id', 'price', 'shipping']

# %%
# 수치형 컬럼의 시각화

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# item_condition_id: 카테고리형에 가까우므로 countplot
sns.countplot(x='item_condition_id', data=train, ax=axes[0])
axes[0].set_title('Item Condition Distribution')

# price: 가격은 보통 심하게 오른쪽으로 치우쳐 있음 (right-skewed)
sns.histplot(train['price'], bins=100, ax=axes[1])
axes[1].set_title('Price Distribution')

# price 로그 변환 후 확인
sns.histplot(train['price'][train['price'] > 0].apply(np.log1p), bins=100, ax=axes[2])
axes[2].set_title('Price Distribution (log1p)')

plt.tight_layout()
plt.show()

# %%
train[train['price'] == 0]
# Out:
#          train_id                                  name  item_condition_id  \
# 1325         1325  Alabama Crimson Tide Quality Lanyard                  1
# 2544         2544                         Levi leggings                  3
# 2712         2712          Simple Red Lace Lingerie Top                  3
# 3576         3576      Turquoise 15 Pc Makeup Brush Set                  1
# 3761         3761                        Girls size 7/8                  3
# ...           ...                                   ...                ...
# 1474172   1474172        Homecoming or Dama ivory dress                  2
# 1474198   1474198                    Tie up flannel top                  3
# 1477958   1477958               Rae Dunn Measuring Pear                  3
# 1478519   1478519      4 pairs women's wool boots socks                  1
# 1478813   1478813       New Braven HD Waterprf Wireless                  1
#
#                                              category_name brand_name  price  \
# 1325                       Sports & Outdoors/Fan Shop/NCAA        NaN    0.0
# 2544                              Women/Jeans/Slim, Skinny    Levi's®    0.0
# 2712                    Women/Underwear/G-Strings & Thongs        NaN    0.0
# 3576     Beauty/Tools & Accessories/Makeup Brushes & Tools        NaN    0.0
# 3761                       Kids/Girls (4+)/Tops & T-Shirts        NaN    0.0
# ...                                                    ...        ...    ...
# 1474172                     Women/Dresses/Above Knee, Mini        NaN    0.0
# 1474198                        Women/Tops & Blouses/Blouse        NaN    0.0
# 1477958                 Home/Home Décor/Home Décor Accents        NaN    0.0
# 1478519                                  Women/Shoes/Boots        NaN    0.0
# 1478813  Electronics/TV, Audio & Surveillance/Home Spea...        NaN    0.0
#
#          shipping                                   item_description
# 1325            1  TOP QUALITY THICK LANYARD Reversible sides wit...
# 2544            0  Light wash. Hardly worn. Size 24 but fits like...
# 2712            0  Very simple but cute, a little form fitting as...
# 3576            1                                            1 left!
# 3761            1  5 pair gap jean excellent used condition 3 chi...
# ...           ...                                                ...
# 1474172         0  Ivory formal dress. I wore this dress once for...
# 1474198         1  I got this last year and just didnt wear it mu...
# 1477958         0  The dash lid appears it was dropped and a piec...
# 1478519         1  ✔️SHARE YOUR SOCKS WITH FRIENDS AND FAMILY! ✔️...
# 1478813         0  The BRV-1 gives action sports and outdoor enth...
#
# [874 rows x 8 columns]

# %%
# 가격이 0인 데이터가 있는지 꼭 확인
print(f"price == 0 인 행 수: {(train['price'] == 0).sum()}")
# Out:
# price == 0 인 행 수: 874

# %% [markdown]
# ### 2. 데이터 전처리 (결측치, 이상치)

# %%
# 전체 결측치 현황 한눈에 보기
print("=== 결측치 현황 ===")
print(train.isna().sum())
# Out:
# === 결측치 현황 ===
# train_id                  0
# name                      0
# item_condition_id         0
# category_name          6327
# brand_name           632682
# price                     0
# shipping                  0
# item_description          6
# dtype: int64

# %%
# 세부 컬럼별 결측치 확인
# 'category_name' 컬럼

print(f"\n▣ category_name 결측치 수: {train['category_name'].isna().sum()}")
print(f"▣ 전체 대비 비율: {train['category_name'].isna().mean()*100:.2f}%")

# 결측치 샘플 확인 - 어떤 상품들인지 보기
null_category = train[train['category_name'].isna()][
    ['name', 'brand_name', 'item_description', 'price']
].sample(20, random_state=42)

print("\n=== category_name 결측 샘플 ===")
print(null_category.to_string())
# Out:
# ▣ category_name 결측치 수: 6327
# ▣ 전체 대비 비율: 0.43%
#
# === category_name 결측 샘플 ===
#                                              name      brand_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         item_description  price
# 245817                             Mini deep dome         Zoo Med                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Zoo Med mini deep Dome brand new in box   10.0
# 1375593                          Lularoe Jaxon Xl             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                           This SOLID BLACK Lularoe jean jacket will go with everything in your wardrobe. It also has spandex in it and hidden pockets inside the jacket!  100.0
# 745172    Dog Leash & Collar Set By Juicy Couture             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Item is new in an unopened package   22.0
# 823760                            North Face Coat  The North Face                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       No description yet   35.0
# 1012577                           For Dear Monica             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                   Bundle includes a quality Dolman Top, a baby blue v-neck shirt, a Wrapped Maxi Skirt, a flare sleeves Top and a pair of Polka Dots palazzo. A gift will be sent alone.  171.0
# 991076           9 assorted Disney Star Wars Pins          Disney                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 You get all 9 pins featured in the photo   20.0
# 621070                               Doggie Steps             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Brought off Groupon and my nephew got more use out the stairs then my dog   21.0
# 1468508         Disney Showcase Collection Minnie          Disney                                                                                                                                                                                                                                                  FOR JASPI.... both Mickey and Minnie!! Perfect condition! From Jim Shore and Disney Traditions collections. Classic Minnie Mouse "Good-hearted Gal" #4056758 *FREE SHIPPING* •PLEASE SEE MY OTHER LISTING THAT HAS MATCHING MICKEY MOUSE ~BUY BOTH TOGETHER FOR REDUCED PRICE• Tags: WDW, Mickey Mouse, Collector, collectible, figure, figurine, decor   50.0
# 849383     Sterling Silver Choker 《Free Shipping》             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Retail: [rm] Brand new, never used Guiliana adjustable choker. Smoke & pet free home. Let's talk about bundling :)   12.0
# 671487   Star Wars Funko Smuggler's Bounty Bundle       Star Wars  Includes Han Solo and Greedo salt and pepper shakers, Wampa MyMoji, wristbands, Droids patch and 40th Anniversary patch. Price is firm and includes USPS first class shipping and packing materials. If you would like to insure your package against damage done in transit, additional costs will be added for priority shipping. I will not be held responsible for packages damaged by USPS if insurance is not purchased. Sold as is. Please note that Funko pops and boxes will NOT be described as mint. Every item is subject to imperfections. Additional photos can be provided upon request.   11.0
# 326448                                 Army Pants            Army                                                                                                                                                                                                                                                                                                                                                                                                                                                  Brand new in great condition men's Army pants. Waist size is 31 to 35in. Message for more info about this product below. Price is firm! HAPPY SHOPPING!    8.0
# 680520                         Zantrex-3 60 count             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Weight loss pills 60 count bottle still sealed. Normally [rm] in stores.   19.0
# 436670                               Roxy Sweater            Roxy                                                                                                                                                                                                                                                                                                                                                                                                                                                                Wool-like warm sweater from Roxy! Well worn but has a lot of life left! I only have 2 weeks to sell it before it ends up in my yard sale.    9.0
# 1096846     Carter's 2 Piece Christmas Pajamas 5T        Carter's                                                                                                                                                                                                                                                                                                                                                                                                                                                           Size: 5T Carter's 100% Cotton Excellent Used Condition No tears, stains, holes, or other signs of wear. Any questions please feel free to ask!    8.0
# 412735            Chance The rapper on teen vogue             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             New magazine    6.0
# 275704                                    Wedding             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Wedding Sign    9.0
# 123973                         10 Random Stickers             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       No description yet    3.0
# 1437739                      Dog Hoodie BRAND NEW             NaN                                                                                                                                                                                                                                                                                                                                                                                                                          Got this thinking it would fit my small boxer since it's an XL. No such luck. More for a shihtzu or smaller Bichon. Small Boston terrier. Would fit a dog between 12 and 20 lbs    8.0
# 909703                              Panama Bundle             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Panama purse and change holder. MADE IN PANAMA!   14.0
# 724412                                   Emily630             NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       No description yet   34.0

# %%
# 'brand_name' 컬럼

print(f"\n▣ brand_name 결측치 수: {train['brand_name'].isna().sum()}")
print(f"▣ 전체 대비 비율: {train['brand_name'].isna().mean()*100:.2f}%")

# 결측치 샘플 확인 - 어떤 상품들인지 보기
null_brand = train[train['brand_name'].isna()][
    ['name', 'category_name', 'item_description', 'price']
].sample(20, random_state=42)

print("\n=== brand_name 결측 샘플 ===")
print(null_brand.to_string())
# Out:
# ▣ brand_name 결측치 수: 632682
# ▣ 전체 대비 비율: 42.68%
#
# === brand_name 결측 샘플 ===
#                                              name                                   category_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                    item_description  price
# 519130                  Perfume & necklace Bundle                          Beauty/Fragrance/Women                                                                                                                                                                                                                                                                                                                                                                                                                                                                  No description yet   24.0
# 332821                TOMS Gray & Blue Classics 9                           Kids/Boys 2T-5T/Shoes  Well, I forgot that I bought these adorable TOMS for my daughter and her cousins and now they are too small. Oops! My loss is your gain - get these beauties, brand new with tags, at a great price!! Originally [rm] + shipping, these come with original box, NO shoe bag, sorry :( Size 9 classic TOMS slip ons in fun gray camo with blue soles. Size 9 best fits children around age 3-6 (depending on child's size, but please check before purchasing this is only a guide)   26.0
# 393861                      50 Thank you stickers                    Handmade/Paper Goods/Sticker                                                                                                                                                                                                                                                                                                             1" Inch Round Thank You Stickers gold with Red Heart Labels. These are the size of a quarter. The stickers are not on a roll, you will receive 8 sheets with 5 on each.    4.0
# 1411304                                 Eyelashes                              Beauty/Makeup/Eyes                                                                                                                                                                                                                                                                                                                                                                                                                                                                          2 packages   15.0
# 303073                  Vera Bradley stocking (1)                               Other/Other/Other                                                                                                                                                                                                                                                                                                                                                                                                                                           Brand new full size Vera Bradley stocking   12.0
# 1265329                    Red & Gold Jewelry Set                         Women/Jewelry/Necklaces                                                                                                                                                                                                                                                                                                                                                                                                            Gold plated, red beads and gems. Necklace, earrings, Tika/necklace piece    8.0
# 840136   The Big bang theory season 9 blu ray new                       Electronics/Media/Blu-Ray                                                                                                                                                                                                                                                                                                                                                                                           The big bang theory season 9 blu ray combo brand new sealed. Check out my other listings.   20.0
# 1338384    Size 6.5 Women's Clark's Artisan Shoes                  Women/Shoes/Loafers & Slip-Ons                                                                                                                                                                                                                                                                          Not from a smoke free residence. Nice pair of shoes. I usually ship before the 4-7 day period. You can make an offer, just don't low ball. I just want to get rid of this stuff. ASK ABOUT BUNDLING STUFF!   16.0
# 1297417               FreeShip 1 Hookah Pen Mango                               Other/Other/Other                                                                                                                                                                                                                                This is a listing for 1 mango hookah pen. Each pen is up to 500 puffs and contains no nicotine or tobacco and is completely disposable. I have 35 other flavors and many other listings! Feel free to ask if you don't see what you are looking for.    8.0
# 355069                  Black Fleece Line Legging  Women/Athletic Apparel/Pants, Tights, Leggings                                                                                                                                                                                                                                                         Womens Plus Size Fleece Lined Leggings Warm Thick Winter Stretch Basic SizE: L,XL,2X,3X MATERIAL 90% NYLON, 10% SPANDEX CONDITION NEW WITH TAGS LENGTH FULL Length AVAILABLE ️Color: ️Navy blue , grey, dark brown , black.   12.0
# 100735   TWO 2 lush bath bombs supernova pink new                         Beauty/Bath & Body/Bath                                                                                                                                                                                                                                                                                                                                                                          Listing is for 2 brand new lush supernova bath bombs from the lush kitchen uk will be packed very securely   20.0
# 53724                             Women Hooey Hat                               Women/Other/Other                                                                                                                                                                                                                                                                                                                                                                                         Never used, perfect conditons. Colors-Grey,light blue,and pink Messege me for any question!   16.0
# 74435                            Forgiveness Book                Other/Books/Literature & Fiction                                                                                                                                                                                                                                                                                                                                                                                                                                            Forgiveness book a memoir Chiquis Rivera    9.0
# 372542                              Black booties                               Women/Shoes/Boots                                                                                                                                                                                                                                                                                                                                                                                                                                                  NEVER USED!!! In great condition!!   25.0
# 268190    LuLaRoe TC Peacock Feather Leggings NWT  Women/Athletic Apparel/Pants, Tights, Leggings                                                                                                                                                                                                                                                                                                           New and never worn. Beautiful print! Message me to upgrade to Priority Shipping for an additional [rm]. I am not a consultant. Negative pricing comments will be deleted.   40.0
# 11540                           Chala Purse Charm                    Women/Women's Handbags/Other                                                                                                                                                                                                                                                                                                                                                                                 Chala purse charm with dragonfly, butterfly and flower. Can also be used as a key ring. New/sealed.   10.0
# 674405       Turtle Opal Necklace Sterling silver                         Women/Jewelry/Necklaces                                                                                                                                                                                                                                                                                                                                                           Turtle Opal Necklace .Chain is 17" long. The pendant is 1 3/4" X 3 16" wide .Great stocking stuffer for Turtle lovers!!!!   12.0
# 651610       NWT Toms classic canvas shoe size 12                  Women/Shoes/Loafers & Slip-Ons                                                                                                                                                                                                                                                                                                                                                                                                                                                           New in box. Women size 12   36.0
# 739524                    XL Halter Zip up dress!                  Women/Dresses/Above Knee, Mini                                                                                                                                                                                                                                 NWT and lightweight! Color: black with gold zipper. Size: XL Tags: Charlotte Russe Forever 21 Forever 21 plus Faith 21 Torrid H&M Vanity Urban outfitters Victoria secret Pink Papaya Agaci Hollister Abercrombie & Fitch American Eagle Outfitters   12.0
# 759059          One Wheel 3D Nail Art Acrylic And                             Beauty/Makeup/Nails                                                                                                                                                                                                                      One small Wheel 3D Nail Art Acrylic rhinestone style Nail jewelry and 1 feather water Decals for nails. Free Shipping in USA. Feel free to touch our picture to review other items we have in our profile or virtual store. All of our items ship free in USA.    4.0

# %%
# 'item_description' 컬럼

print(f"\n▣ item_description 결측치 수: {train['item_description'].isna().sum()}")
print(f"▣ 전체 대비 비율: {train['item_description'].isna().mean()*100:.2f}%")

# 결측치 샘플 확인 - 어떤 상품들인지 보기
null_description = train[train['item_description'].isna()][
    ['name', 'category_name', 'brand_name', 'price']
].sample(6, random_state=42)

print("\n=== item_description 결측 샘플 ===")
print(null_description.to_string())
# Out:
# ▣ item_description 결측치 수: 6
# ▣ 전체 대비 비율: 0.00%
#
# === item_description 결측 샘플 ===
#                             name                                   category_name           brand_name  price
# 321916        Lululemon leggings  Women/Athletic Apparel/Pants, Tights, Leggings  lululemon athletica   44.0
# 511535        Shoes for Michelle                       Kids/Girls 0-24 Mos/Shoes                  NaN    9.0
# 1425077            Lg 25um65p x2                         Electronics/Other/Other                  NaN  230.0
# 861230                  Lipgloss                              Beauty/Makeup/Lips                  NaN   49.0
# 1264242               For Bianca       Women/Women's Accessories/Scarves & Wraps                  NaN   10.0
# 1224924  Disney Minnie Head band      Women/Women's Accessories/Hair Accessories               Disney    9.0

# %%
# 'item_description' 결측치 : 'No description yet'과 동일한 값으로 처리
train['item_description'] = train['item_description'].fillna("No description yet")

# %%
# 'brand_name' 결측치 처리 :
# 1. 기존 브랜드명이 기재된 컬럼에는 1, 누락된 곳에는 0
# 2. 결측치처리 : 'No Brand'
train["has_brand"] = train["brand_name"].notna().astype(int)
train["brand_name"] = train["brand_name"].fillna("No Brand")

# %%
# 'category_name' 결측치 처리 : 'No Category/No category/No category' - 기존 카테고리 분류 형식과 동일하게
train["category_name"] = train["category_name"].fillna("No category/No category/No category")

# %%
# 처리 후 전체 결측치 현황 한눈에 보기
print("=== 결측치 처리 후 데이터 결측치 현황 ===")
print(train.isna().sum())
# Out:
# === 결측치 처리 후 데이터 결측치 현황 ===
# train_id             0
# name                 0
# item_condition_id    0
# category_name        0
# brand_name           0
# price                0
# shipping             0
# item_description     0
# has_brand            0
# dtype: int64

# %%
print(f"'No description yet'인 행 수 : {(train['item_description']=='No description yet').sum()}")
# Out:
# 'No description yet'인 행 수 : 82495

# %%
train[train['item_description']=='No description yet']
# Out:
#          train_id                                 name  item_condition_id  \
# 0               0  MLB Cincinnati Reds T Shirt Size XL                  3
# 13             13                 Sharpener and eraser                  1
# 31             31       New Lularoe OS leggings, stars                  1
# 90             90                         Jewel holder                  2
# 117           117                Eyeko liquid eyeliner                  1
# ...           ...                                  ...                ...
# 1482430   1482430                     Nike Jordan's 5c                  3
# 1482447   1482447                 Wet n Wild Eyelashes                  2
# 1482470   1482470                   Adidas ultra boost                  2
# 1482496   1482496         Benefit they're real mascara                  1
# 1482498   1482498    Cupquake beauty rush mist ON HOLD                  3
#
#                                              category_name  brand_name  price  \
# 0                                        Men/Tops/T-shirts    No Brand   10.0
# 13                   Other/Office supplies/School Supplies  Scholastic    4.0
# 31          Women/Athletic Apparel/Pants, Tights, Leggings    No Brand   50.0
# 90       Home/Storage & Organization/Jewelry Boxes & Or...      Target    7.0
# 117                                     Beauty/Makeup/Eyes    No Brand    5.0
# ...                                                    ...         ...    ...
# 1482430                             Kids/Girls 2T-5T/Shoes        Nike   14.0
# 1482447                                 Beauty/Makeup/Eyes  Wet n Wild    3.0
# 1482470                                 Men/Shoes/Athletic      Adidas    9.0
# 1482496                                 Beauty/Makeup/Eyes     Benefit    8.0
# 1482498                             Beauty/Fragrance/Women    No Brand   27.0
#
#          shipping    item_description  has_brand
# 0               1  No description yet          0
# 13              1  No description yet          1
# 31              1  No description yet          0
# 90              1  No description yet          1
# 117             1  No description yet          0
# ...           ...                 ...        ...
# 1482430         0  No description yet          1
# 1482447         1  No description yet          1
# 1482470         0  No description yet          1
# 1482496         1  No description yet          1
# 1482498         0  No description yet          0
#
# [82495 rows x 9 columns]

# %% [markdown]
# category_name 분리

# %%
# 카테고리 분리 적용
train[['cat_1', 'cat_2', 'cat_3']] = train['category_name'].str.split('/', n=2, expand=True)

print(train['cat_1'].value_counts().head(10))  # 상위 카테고리 확인
# Out:
# cat_1
# Women                     664385
# Beauty                    207828
# Kids                      171689
# Electronics               122690
# Men                        93680
# Home                       67871
# Vintage & Collectibles     46530
# Other                      45351
# Handmade                   30842
# Sports & Outdoors          25342
# Name: count, dtype: int64

# %%
train.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts   No Brand   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents   No Brand   35.0
# 4                            Women/Jewelry/Necklaces   No Brand   44.0
#
#    shipping                                   item_description  has_brand  \
# 0         1                                 No description yet          0
# 1         0  This keyboard is in great condition and works ...          1
# 2         1  Adorable top with a hint of lace and a key hol...          1
# 3         1  New with tags. Leather horses. Retail for [rm]...          0
# 4         0          Complete with certificate of authenticity          0
#
#          cat_1                cat_2               cat_3
# 0          Men                 Tops            T-shirts
# 1  Electronics  Computers & Tablets  Components & Parts
# 2        Women       Tops & Blouses              Blouse
# 3         Home           Home Décor  Home Décor Accents
# 4        Women              Jewelry           Necklaces

# %%
train_filtered = train[
    (train['cat_1'] == "Beauty") | (train['cat_1'] == "Women")
]

# %%
train_filtered.shape
train_filtered.info()
train_filtered.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 872213 entries, 2 to 1482534
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   train_id           872213 non-null  int64
#  1   name               872213 non-null  object
#  2   item_condition_id  872213 non-null  int64
#  3   category_name      872213 non-null  object
#  4   brand_name         872213 non-null  object
#  5   price              872213 non-null  float64
#  6   shipping           872213 non-null  int64
#  7   item_description   872213 non-null  object
#  8   has_brand          872213 non-null  int64
#  9   cat_1              872213 non-null  object
#  10  cat_2              872213 non-null  object
#  11  cat_3              872213 non-null  object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 86.5+ MB
#            train_id  item_condition_id          price      shipping  \
# count  8.722130e+05      872213.000000  872213.000000  872213.00000
# mean   7.410850e+05           1.881374      26.690024       0.44370
# std    4.280426e+05           0.880100      36.183223       0.49682
# min    2.000000e+00           1.000000       0.000000       0.00000
# 25%    3.703280e+05           1.000000      11.000000       0.00000
# 50%    7.410200e+05           2.000000      18.000000       0.00000
# 75%    1.111454e+06           3.000000      30.000000       1.00000
# max    1.482534e+06           5.000000    2009.000000       1.00000
#
#            has_brand
# count  872213.000000
# mean        0.647928
# std         0.477617
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
train_filtered['cat_1'].value_counts()
# Out:
# cat_1
# Women     664385
# Beauty    207828
# Name: count, dtype: int64

# %%
train_filtered.groupby('cat_1')['price'].describe()
# Out:
#            count       mean        std  min   25%   50%   75%     max
# cat_1
# Beauty  207828.0  19.671536  21.360135  0.0  10.0  15.0  24.0  2000.0
# Women   664385.0  28.885496  39.443853  0.0  12.0  19.0  33.0  2009.0

# %%
import seaborn as sns

sns.boxplot(x='cat_1', y='price_log', data=train_filtered)
plt.show()

# %%
train_filtered.groupby('item_condition_id')['price'].mean()
# Out:
# item_condition_id
# 1    27.616745
# 2    26.547086
# 3    25.720079
# 4    21.684153
# 5    21.543321
# Name: price, dtype: float64

# %%
train_filtered['price_log'] = np.log1p(train_filtered['price'])

train_filtered.groupby('item_condition_id')['price_log'].mean()
# Out:
# C:\Users\TG\AppData\Local\Temp\ipykernel_23660\976607570.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_filtered['price_log'] = np.log1p(train_filtered['price'])
# item_condition_id
# 1    3.042895
# 2    3.015640
# 3    2.979396
# 4    2.830768
# 5    2.779921
# Name: price_log, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='item_condition_id', y='price_log', data=train_filtered)
plt.title("Condition vs Log Price")
plt.show()

# %%
train_filtered['item_condition_id'].value_counts()
# Out:
# item_condition_id
# 1    378041
# 3    240982
# 2    236671
# 4     15965
# 5       554
# Name: count, dtype: int64

# %%
train_filtered['brand_name'].isnull().mean()
# Out:
# np.float64(0.0)

# %%
train_filtered.groupby(train_filtered['brand_name'].isnull())['price'].mean()
# Out:
# brand_name
# False    26.690024
# Name: price, dtype: float64

# %% [markdown]
# Condition 분석

# %%
cond_dist = train_filtered['item_condition_id'].value_counts().sort_index()
cond_ratio = train_filtered['item_condition_id'].value_counts(normalize=True).sort_index()

pd.DataFrame({
    "Count": cond_dist,
    "Ratio": cond_ratio
})
# Out:
#                     Count     Ratio
# item_condition_id
# 1                  378041  0.433427
# 2                  236671  0.271345
# 3                  240982  0.276288
# 4                   15965  0.018304
# 5                     554  0.000635

# %% [markdown]
# condition 1이가장많다. 43퍼> 거의 절반이 '신상품 또는 최상상태
# 23도 합치면 약 55 전체의 98퍼가 1~3구간
# 심한 중고상품은 거의 등록 x
#
# 이시장은 '중고 마켓이지만 신상품 중심 구조
# 즉 재고 처분 및 미개봉 상품 중심

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='item_condition_id', data=train_filtered)
plt.title("Distribution of Item Condition")
plt.xlabel("Item Condition")
plt.ylabel("Count")
plt.show()

# %%
train_filtered.groupby('item_condition_id')['price'].agg(['mean','median','count'])
# Out:
#                         mean  median   count
# item_condition_id
# 1                  27.616745    19.0  378041
# 2                  26.547086    18.0  236671
# 3                  25.720079    16.0  240982
# 4                  21.684153    14.0   15965
# 5                  21.543321    13.0     554

# %%
import numpy as np

train_filtered['price_log'] = np.log1p(train_filtered['price'])

sns.boxplot(x='item_condition_id', y='price_log', data=train_filtered)
plt.title("Condition vs Log Price")
plt.show()
# Out:
# C:\Users\TG\AppData\Local\Temp\ipykernel_23660\4039674047.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_filtered['price_log'] = np.log1p(train_filtered['price'])

# %% [markdown]
# 1>5로 갈수록 평균/중앙값 꾸준히 하락> 시장이 상태를 가격에 반영하고있음
#
# 차이는 크지않지만 병확한 방향성이있음
# 컨디션 1vs5 평균차이 약 6달러 중앙값도 19에서 13으로 하락 일관되게 감소
#
# 박스플롯
# 컨디션 1이 중앙값이 가장높음
# 컨디션 45는 박스 자체가 아래쪽에 위치
# 고가 아웃라이어는 대부분 1~3에 존재

# %% [markdown]
# Shipping 분석

# %%
ship_dist = train_filtered['shipping'].value_counts()
ship_ratio = train_filtered['shipping'].value_counts(normalize=True)

pd.DataFrame({
    "Count": ship_dist,
    "Ratio": ship_ratio
})
# Out:
#            Count   Ratio
# shipping
# 0         485212  0.5563
# 1         387001  0.4437

# %%
sns.countplot(x='shipping', data=train_filtered)
plt.title("Shipping Distribution (1=Seller pays)")
plt.show()

# %% [markdown]
# 구매자 부담이 더 많다. 거진 반반이긴함근데  결론은 무료배송이 기본은 아니고 무료배송 전략을 쓰는 판매자도 많고 배송비 별도 전략도 꽤 이용됨 > 배송전략이 경쟁 요소로 작용하는 시장이다.~

# %%
train_filtered.groupby('shipping')['price'].agg(['mean','median','count'])
# Out:
#                mean  median   count
# shipping
# 0         29.474628    20.0  485212
# 1         23.198759    15.0  387001

# %%
sns.boxplot(x='shipping', y='price_log', data=train_filtered)
plt.title("Shipping vs Log Price")
plt.show()

# %% [markdown]
# 무료배송 1 일때 가격이 더 낮다. 평균 6달러 차이 중앙값도 20>15
#
# 무료배송 상품은
#
# 기본 상품 가격을 낮게 설정
# 배송비 포함 전략
# 저가 상품중심
#
# 반대로 구매자 부담 상품은
# 상품자체 가격이 더 높음 고가 상품에서 배송비 별도 전략사용

# %% [markdown]
# condition vs shipping

# %%
pd.pivot_table(
    train_filtered,
    values='price',
    index='item_condition_id',
    columns='shipping',
    aggfunc=['mean','median','count']
)
# Out:
#                         mean            median         count
# shipping                   0          1      0     1       0       1
# item_condition_id
# 1                  33.775823  22.944922   24.0  15.0  163065  214976
# 2                  28.079686  23.933914   19.0  15.0  149179   87492
# 3                  26.896207  23.328187   18.0  15.0  161547   79435
# 4                  22.708401  19.375993   16.0  12.0   11058    4907
# 5                  24.181818  16.528796   14.0  12.0     363     191

# %% [markdown]
# 배송비 구매자 부담이 항상 가격이 더높다.

# %%
sns.boxplot(
    x='item_condition_id',
    y='price_log',
    hue='shipping',
    data=train_filtered
)
plt.title("Condition × Shipping vs Log Price")
plt.show()

# %% [markdown]
# 파란색이 항상 위에있음
# 특히 컨디션 1에서 격차가 제일 크고 고가 아웃아리어 대부분이 shipping  0

# %% [markdown]
# 판매자 인사이트
# 컨디션 1 고가 전략이면 배송비 별도가능
# 저가 경쟁 구간은 무료배송이 기본
# 무료배송이 항상 유리한건아님
#
#
# Condition과 Shipping을 교차 분석한 결과,
# 모든 상태 구간에서 배송비 구매자 부담 상품이
# 더 높은 평균 가격을 형성하고 있었다.
# 특히 Condition 1에서 가격 차이가 가장 크게 나타났으며,
# 이는 프리미엄 상품일수록 배송비 별도 전략이 활용됨을 시사한다.
